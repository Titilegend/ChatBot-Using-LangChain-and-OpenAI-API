# %% [markdown]
# <a href="https://colab.research.google.com/github/Titilegend/ChatBot-Using-LangChain-and-OpenAI-API/blob/main/AI_ENGINEERING_TASK_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task:
#
# Simple chatbot using LangChain & OpenAI API — create a notebook or script that accepts user questions and returns answers using LangChain chains; test with 5 sample queries and include setup notes (API key usage, env vars).

# %%
# !pip install -U langchain langchain-openai python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 kB 996.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 kB 19.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.8
#     Uninstalling langchain-core-1.2.8:
#       Successfully uninstalled langchain-core-1.2.8
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.8
#     Uninstalling langchain-1.2.8:
#       Successfully uninstalled langchain-1.2.8
# ...

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")

if not os.environ["OPENAI_API_KEY"]:
    raise ValueError("OPENAI_API_KEY is not found")

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant. Answer clearly and concisely"),
    ("user","{question}")
])


llm = ChatOpenAI(model = "gpt-4o-mini",temperature=0.2)

chain = prompt | llm | StrOutputParser()

# %%
tests = [

         "What is LangChain in one paragraph?",
         "Explain Government like I'm 5 years old",
         "Recommend 5 beginner ML Projects using python",
         "Write a short email requesting an email",
         "Difference between SQL nad MySQL?"

]

for i,q in enumerate(tests,1):
  a = chain.invoke({"question": q})
  print(f"Q{i}: {q}\nA{i}: {a}\n" + "-"*60)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-3105589456.py in <cell line: 0>()
#      10
#      11 for i,q in enumerate(tests,1):
# ---> 12   a = chain.invoke({"question": q})
#      13   print(f"Q{i}: {q}\nA{i}: {a}\n" + "-"*60)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3151                         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3152                     else:
# -> 3153                         input_ = context.run(step.invoke, input_, config)
#    3154         # finish the root run
#    3155         except BaseException as e:
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     400             cast(
#     401                 "ChatGeneration",
# ...

# %%
while True:
  q = input("You: ").strip()
  if q.lower() in {"exit","quit"}:
    print("Bot: Goodbye")
    break
  if not q:
    continue
  print("Bot",chain.invoke({"question": q}), "\n")
